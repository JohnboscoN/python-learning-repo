# %%
x= 4
y=3
z = x+y

print(z)
print('hello world')
z
# Out:
# 7
# hello world
# 7

# %%
a = 3
b = 7
c = a*b
print(c)
# Out:
# 21

# %%
radius = 2
pi = 3.14
radiussqd = 2**2
area = pi * radiussqd
print(area)
print(pi *(radius**2))
# Out:
# 12.56
# 12.56

# %%
p1 = "Hi, I am "
p2  = " Will"
print(p1+p2)
print ("f {p1}")
# Out:
# Hi, I am  Will

# %%
slice = 'dog cat racoon'
print(slice[0:4])
print(slice[4:8])
print(slice[8:])
# Out:
# dog
# cat
# racoon
